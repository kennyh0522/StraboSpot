# %% [markdown]
# This cell is used to determine what features are important to the clustering. By disregarding the features that are identical across all of the clusters,
# you are left with around 12 features. Among those features, if there is significant difference in the presence of that data among the cluster and the entire
# data set, the feature must be important in how the clustering was determined.

# %%
import pandas as pd
from kmodes.kmodes import KModes
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2, f_classif
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import pickle
import kmodes as KModes
import seaborn as sns

# %%
df = pd.read_csv("../data/parquets/kmodes_clustered_parquet.csv")

# %%
with open('../models/kmodes_model_parquet.pkl', 'rb') as f:
    km = pickle.load(f)

# %%
features = df.columns.tolist()[:-1] #does every feature in df except cluster
centroids = km.cluster_centroids_

# %% [markdown]
# For most features, the modes of each cluster are identical, whether it be that a feature is present across all clusters or is missing. Because of this,
# the features that are identical have no variance and therefore do not help to understand what features may be important. This cell is used to determine
# what what features have modes that differ across the clusters.

# %%
unique_modes_features = []
for feature_idx, feature in enumerate(features):
    modes_across_clusters = [centroids[c][feature_idx] for c in range(len(centroids))]
    unique_modes = len(set(modes_across_clusters))
    if unique_modes > 1:
        unique_modes_features.append(feature)

# %% [markdown]
# For every cluster, this cell will print the mode of the unique features determined in the cell above and how prevalent/absent the feature is within the
# cluster and within the entire dataset. If a feature is roughly equally present in the cluster and the data set, the cluster is likely not important to
# defining the cluster. A factor of two has been arbitrarily chosen to determine what features might be particularly defining of the cluster. If a feature in
# the cluster is either twice or half as present/absent compared the data set, the feature likely contriubutes heavily to how the cluster was determined and
# is labeled at the bottom of each cluster with the feature name, mode value, presence in cluster, and presence in dataset.

# %%
for cluster in range(len(centroids)):
    print(f"\n{'='*50}")
    print(f"Cluster {cluster}")
    print(f"{'='*50}")
    
    cluster_data = df[df["cluster"] == cluster]
    print(f"Size: {len(cluster_data)} samples\n")
    # print("Distinguishing features:")
    important_features = []
    for feature in unique_modes_features:
        feature_idx = features.index(feature)
        mode_value = centroids[cluster][feature_idx]
        count = (cluster_data[feature] == mode_value).sum()
        cluster_prevalence = (count / len(cluster_data)) * 100
        df_prevalence = (len(df[df[feature] == mode_value]) / df[feature].shape[0]) * 100 #prevalence of a value in a feature across the entre df
        print(f"  {feature}: {mode_value} ({cluster_prevalence:.1f}%) || ({df_prevalence:.1f}%)")
        
        if max(cluster_prevalence, df_prevalence) / min(cluster_prevalence, df_prevalence) >= 2:
            important_features.append((feature, mode_value, cluster_prevalence, df_prevalence, cluster))
    
    print("")
    print(f"Cluster {cluster} Defining Features:")
    for feature in important_features:
        print(f"** {feature[0]}: {feature[1]} \n\t({feature[2]:.1f}%) Prevalence in Cluster \n\t({feature[3]:.1f}%) Prevalence in dataset")
# Out:
# ==================================================
# Cluster 0
# ==================================================
# Size: 270930 samples
#
#   properties_images: 0 (88.9%) || (88.0%)
#   properties_notes: 0 (100.0%) || (79.3%)
#   properties_orientation_data: 1 (100.0%) || (31.5%)
#   properties_lng: 0 (100.0%) || (97.9%)
#   properties_image_basemap: 0 (99.5%) || (97.8%)
#   properties_lat: 0 (100.0%) || (97.9%)
#   properties_trace_trace_feature: 0 (99.9%) || (96.2%)
#   properties_trace_trace_quality: 0 (100.0%) || (97.1%)
#   properties_trace_trace_type: 0 (99.9%) || (96.2%)
#
# Cluster 0 Defining Features:
# ** properties_orientation_data: 1
# 	(100.0%) Prevalence in Cluster
# 	(31.5%) Prevalence in dataset
#
# ==================================================
# Cluster 1
# ==================================================
# Size: 52914 samples
#
#   properties_images: 1 (100.0%) || (12.0%)
#   properties_notes: 0 (100.0%) || (79.3%)
#   properties_orientation_data: 0 (100.0%) || (68.5%)
#   properties_lng: 0 (97.5%) || (97.9%)
#   properties_image_basemap: 0 (99.3%) || (97.8%)
#   properties_lat: 0 (97.5%) || (97.9%)
#   properties_trace_trace_feature: 0 (100.0%) || (96.2%)
#   properties_trace_trace_quality: 0 (100.0%) || (97.1%)
#   properties_trace_trace_type: 0 (100.0%) || (96.2%)
#
# Cluster 1 Defining Features:
# ** properties_images: 1
# 	(100.0%) Prevalence in Cluster
# 	(12.0%) Prevalence in dataset
#
# ==================================================
# Cluster 2
# ==================================================
# Size: 23512 samples
#
#   properties_images: 0 (70.3%) || (88.0%)
#   properties_notes: 0 (76.7%) || (79.3%)
#   properties_orientation_data: 0 (72.2%) || (68.5%)
#   properties_lng: 1 (100.0%) || (2.1%)
#   properties_image_basemap: 1 (83.1%) || (2.2%)
#   properties_lat: 1 (100.0%) || (2.1%)
#   properties_trace_trace_feature: 0 (98.3%) || (96.2%)
#   properties_trace_trace_quality: 0 (98.4%) || (97.1%)
#   properties_trace_trace_type: 0 (98.3%) || (96.2%)
#
# Cluster 2 Defining Features:
# ** properties_lng: 1
# 	(100.0%) Prevalence in Cluster
# 	(2.1%) Prevalence in dataset
# ** properties_image_basemap: 1
# 	(83.1%) Prevalence in Cluster
# 	(2.2%) Prevalence in dataset
# ** properties_lat: 1
# 	(100.0%) Prevalence in Cluster
# 	(2.1%) Prevalence in dataset
#
# ==================================================
# Cluster 3
# ==================================================
# Size: 108945 samples
#
#   properties_images: 0 (59.2%) || (88.0%)
#   properties_notes: 1 (100.0%) || (20.7%)
#   properties_orientation_data: 1 (100.0%) || (31.5%)
#   properties_lng: 0 (100.0%) || (97.9%)
#   properties_image_basemap: 0 (99.6%) || (97.8%)
#   properties_lat: 0 (100.0%) || (97.9%)
#   properties_trace_trace_feature: 0 (99.7%) || (96.2%)
#   properties_trace_trace_quality: 0 (99.9%) || (97.1%)
#   properties_trace_trace_type: 0 (99.7%) || (96.2%)
#
# Cluster 3 Defining Features:
# ** properties_notes: 1
# 	(100.0%) Prevalence in Cluster
# 	(20.7%) Prevalence in dataset
# ** properties_orientation_data: 1
# 	(100.0%) Prevalence in Cluster
# 	(31.5%) Prevalence in dataset
#
# ==================================================
# Cluster 4
# ==================================================
# Size: 592049 samples
#
#   properties_images: 0 (100.0%) || (88.0%)
#   properties_notes: 0 (100.0%) || (79.3%)
#   properties_orientation_data: 0 (100.0%) || (68.5%)
#   properties_lng: 0 (100.0%) || (97.9%)
#   properties_image_basemap: 0 (99.5%) || (97.8%)
#   properties_lat: 0 (100.0%) || (97.9%)
#   properties_trace_trace_feature: 0 (99.9%) || (96.2%)
#   properties_trace_trace_quality: 0 (100.0%) || (97.1%)
#   properties_trace_trace_type: 0 (100.0%) || (96.2%)
#
# Cluster 4 Defining Features:
#
# ==================================================
# Cluster 5
# ==================================================
# Size: 135959 samples
#
#   properties_images: 0 (90.6%) || (88.0%)
#   properties_notes: 1 (100.0%) || (20.7%)
#   properties_orientation_data: 0 (100.0%) || (68.5%)
#   properties_lng: 0 (99.8%) || (97.9%)
#   properties_image_basemap: 0 (99.2%) || (97.8%)
#   properties_lat: 0 (99.8%) || (97.9%)
#   properties_trace_trace_feature: 0 (99.7%) || (96.2%)
#   properties_trace_trace_quality: 0 (100.0%) || (97.1%)
#   properties_trace_trace_type: 0 (99.7%) || (96.2%)
#
# Cluster 5 Defining Features:
# ** properties_notes: 1
# 	(100.0%) Prevalence in Cluster
# 	(20.7%) Prevalence in dataset
#
# ==================================================
# Cluster 6
# ==================================================
# Size: 45065 samples
#
#   properties_images: 0 (99.5%) || (88.0%)
#   properties_notes: 0 (92.2%) || (79.3%)
#   properties_orientation_data: 0 (98.7%) || (68.5%)
#   properties_lng: 0 (100.0%) || (97.9%)
#   properties_image_basemap: 0 (98.4%) || (97.8%)
#   properties_lat: 0 (100.0%) || (97.9%)
#   properties_trace_trace_feature: 1 (100.0%) || (3.8%)
#   properties_trace_trace_quality: 1 (78.3%) || (2.9%)
#   properties_trace_trace_type: 1 (100.0%) || (3.8%)
#
# Cluster 6 Defining Features:
# ** properties_trace_trace_feature: 1
# 	(100.0%) Prevalence in Cluster
# 	(3.8%) Prevalence in dataset
# ** properties_trace_trace_quality: 1
# 	(78.3%) Prevalence in Cluster
# 	(2.9%) Prevalence in dataset
# ** properties_trace_trace_type: 1
# 	(100.0%) Prevalence in Cluster
# 	(3.8%) Prevalence in dataset

# %%
print("Important Features to Look For: ")
for feature in unique_modes_features:
    print(f"\t{feature}")
print(len(unique_modes_features))
# Out:
# Important Features to Look For:
# 	properties_images
# 	properties_notes
# 	properties_orientation_data
# 	properties_lng
# 	properties_image_basemap
# 	properties_lat
# 	properties_trace_trace_feature
# 	properties_trace_trace_quality
# 	properties_trace_trace_type
# 9
