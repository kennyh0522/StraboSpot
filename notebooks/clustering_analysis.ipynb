# %%
"""
This cell is used to determine what features are important to the clustering. By disregarding the features that are identical across all of the clusters,
you are left with around 13 features. Among those features, if there is significant difference in the presence of that data among the cluster and the entire
data set, the feature must be important in how the clustering was determined. 
"""

# %%
import pandas as pd
from kmodes.kmodes import KModes
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2, f_classif
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import pickle
import kmodes as KModes
import seaborn as sns

# %%
df = pd.read_csv("../data/clustered_data.csv")

# %%
def val_count(data):
    counter = 0
    for i in data.columns:
        print(counter)
        print(data[i].value_counts())
        counter += 1
        print("=========================="*5)
    print(data.shape)

# %%
with open('../models/kmodes_model.pkl', 'rb') as f:
    km = pickle.load(f)

# %%
features = df.columns.tolist()[:-1] #does every feature in df except cluster
centroids = km.cluster_centroids_

# %%
"""
For most features, the modes of each cluster are identical, whether it be that a feature is present across all clusters or is missing. Because of this,
the features that are identical have no variance and therefore do not help to understand what features may be important. This cell is used to determine 
what what features have modes that differ across the clusters.
"""

unique_modes_features = []
for feature_idx, feature in enumerate(features):
    modes_across_clusters = [centroids[c][feature_idx] for c in range(len(centroids))]
    unique_modes = len(set(modes_across_clusters))
    if unique_modes > 1:
        unique_modes_features.append(feature)
# Out:
# properties_date: 1 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 1
#   Cluster 3: 1
#   Cluster 4: 1
#   Cluster 5: 1
#   Cluster 6: 1
#   Cluster 7: 1
# properties_trace_trace_feature: 2 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 1
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_trace_type: 2 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 1
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_name: 1 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 1
#   Cluster 3: 1
#   Cluster 4: 1
#   Cluster 5: 1
#   Cluster 6: 1
#   Cluster 7: 1
# properties_time: 1 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 1
#   Cluster 3: 1
#   Cluster 4: 1
#   Cluster 5: 1
#   Cluster 6: 1
#   Cluster 7: 1
# properties_id: 1 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 1
#   Cluster 3: 1
#   Cluster 4: 1
#   Cluster 5: 1
#   Cluster 6: 1
#   Cluster 7: 1
# properties_modified_timestamp: 1 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 1
#   Cluster 3: 1
#   Cluster 4: 1
#   Cluster 5: 1
#   Cluster 6: 1
#   Cluster 7: 1
# properties_self: 1 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 1
#   Cluster 3: 1
#   Cluster 4: 1
#   Cluster 5: 1
#   Cluster 6: 1
#   Cluster 7: 1
# type: 1 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 1
#   Cluster 3: 1
#   Cluster 4: 1
#   Cluster 5: 1
#   Cluster 6: 1
#   Cluster 7: 1
# properties_images: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_images_notes: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_contact_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_trace_notes: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_geologic_structure_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_shear_sense: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_data: 2 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 1
#   Cluster 5: 1
#   Cluster 6: 1
#   Cluster 7: 1
# properties_rock_unit_unit_label_abbreviation: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_map_unit_name: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_notes: 2 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_image_basemap: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_depositional_contact_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_contact_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_trace_quality: 2 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 1
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_symbology_circleColor: 2 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 1
# properties_trace_metamorphic_contact_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_rock_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_metamorphic_rock_types: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_description: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_trace_character: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_inferences_rosetta_outcrop: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_inferences_description_of_outcrop: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_inferences_relationships: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties__3d_structures: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_intrusive_contact_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_other_features: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_fold_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_notes: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_feature: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_sedimentary_rock_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_igneous_rock_class: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_plutonic_rock_types: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_sediment_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_samples: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_inferences_outcrop_in_place: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_other_feature: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_period: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_marker_layer_details: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_strike: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_dip: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_Rake: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_spot_radius_units: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_spot_radius: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_inferences_related_rosetta_outcrop: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_inferences_notes: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_rock_unit_absolute_age_of_geologic_unit: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_tace_notes: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_altitude: 2 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 1
#   Cluster 5: 0
#   Cluster 6: 1
#   Cluster 7: 0
# properties_trace_antropogenic_feature: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_lng: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_lat: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_sed_strat_section_strat_section_id: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_sed_strat_section_column_profile: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_sed_strat_section_column_y_axis_units: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_sed_strat_section_section_well_name: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_sed_strat_section_display_lithology_patterns: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_id: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_quality: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_feature_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_strike: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_dip_direction: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_dip: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_label: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_fold_attitude: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_trend: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_plunge: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_rake: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_rake_calculated: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_depositional_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_fault_or_sz_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_foliation_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_sed_strat_section_section_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_sed_strat_section_purpose: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_geomorphic_feature: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_geomorphic_feature: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_directional_indicators: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_sed_strat_section_misc_labels: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_bedding_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_facing: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_facing_defined_by: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_associated_orientation: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_movement: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_trace_character: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_notes: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_contact_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_anthropogenic_feature: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_viewed_timestamp: 2 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 1
#   Cluster 3: 0
#   Cluster 4: 1
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 1
# properties_symbology_lineColor: 2 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 1
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_symbology_lineWidth: 2 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 1
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_symbology_lineDasharray: 2 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 1
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_gps_accuracy: 2 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 1
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 1
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_trace_quality: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_notesTimestamp: 2 different values across clusters
#   Cluster 0: 1
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_orientation_movement_justification: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_altitude_accuracy: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_shear_sense: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0
# properties_trace_other_fold_type: 1 different values across clusters
#   Cluster 0: 0
#   Cluster 1: 0
#   Cluster 2: 0
#   Cluster 3: 0
#   Cluster 4: 0
#   Cluster 5: 0
#   Cluster 6: 0
#   Cluster 7: 0

# %%
"""
For every cluster, this cell will print the mode of the uniqued features determined in the cell above and how prevalent/absent the feature is within the 
cluster and within the entire dataset. If a feature is roughly equally present in the cluster and the data set, the cluster is likely not important to 
defining the cluster. A factor of two has been arbitrarily chosen to determine what features might be particularly defining of the cluster. If a feature in
the cluster is either twice or half as present/absent compared the data set, the feature likely contriubutes heavily to how the cluster was determined and
is labeled at the bottom of each cluster with the feature name, mode value, presence in cluster, and presence in dataset.
"""


for cluster in range(len(centroids)):
    print(f"\n{'='*50}")
    print(f"Cluster {cluster}")
    print(f"{'='*50}")
    
    cluster_data = df[df["cluster"] == cluster]
    print(f"Size: {len(cluster_data)} samples\n")
    print("Distinguishing features:")
    important_features = []
    for feature in unique_modes_features:
        feature_idx = features.index(feature)
        mode_value = centroids[cluster][feature_idx]
        count = (cluster_data[feature] == mode_value).sum()
        cluster_prevalence = (count / len(cluster_data)) * 100
        df_prevalence = (len(df[df[feature] == mode_value]) / df[feature].shape[0]) * 100 #prevalence of a value in a feature across the entre df
        print(f"  {feature}: {mode_value} ({cluster_prevalence:.1f}%) || ({df_prevalence:.1f}%)")
        
        if max(cluster_prevalence, df_prevalence) / min(cluster_prevalence, df_prevalence) >= 2:
            important_features.append((feature, mode_value, cluster_prevalence, df_prevalence))
    
    for feature in important_features:
        print(f"** Important Feature - {feature[0]}: {feature[1]} ({feature[2]:.1f}%) || ({feature[3]:.1f}%)")
# Out:
# ==================================================
# Cluster 0
# ==================================================
# Size: 1852 samples
#
# Distinguishing features:
#   properties_trace_trace_feature: 0 (100.0%) || (89.4%)
#   properties_trace_trace_type: 0 (100.0%) || (89.4%)
#   properties_orientation_data: 1 (62.6%) || (65.6%)
#   properties_notes: 1 (99.3%) || (8.1%)
#   properties_trace_trace_quality: 0 (100.0%) || (90.3%)
#   properties_symbology_circleColor: 1 (84.5%) || (37.7%)
#   properties_altitude: 1 (59.8%) || (35.2%)
#   properties_viewed_timestamp: 1 (100.0%) || (59.2%)
#   properties_symbology_lineColor: 0 (100.0%) || (94.3%)
#   properties_symbology_lineWidth: 0 (100.0%) || (94.3%)
#   properties_symbology_lineDasharray: 0 (100.0%) || (94.3%)
#   properties_gps_accuracy: 1 (59.8%) || (29.1%)
#   properties_notesTimestamp: 1 (100.0%) || (4.2%)
# ** Important Feature - properties_notes: 1 (99.3%) || (8.1%)
# ** Important Feature - properties_symbology_circleColor: 1 (84.5%) || (37.7%)
# ** Important Feature - properties_gps_accuracy: 1 (59.8%) || (29.1%)
# ** Important Feature - properties_notesTimestamp: 1 (100.0%) || (4.2%)
#
# ==================================================
# Cluster 1
# ==================================================
# Size: 4979 samples
#
# Distinguishing features:
#   properties_trace_trace_feature: 0 (100.0%) || (89.4%)
#   properties_trace_trace_type: 0 (100.0%) || (89.4%)
#   properties_orientation_data: 1 (81.9%) || (65.6%)
#   properties_notes: 0 (100.0%) || (91.9%)
#   properties_trace_trace_quality: 0 (100.0%) || (90.3%)
#   properties_symbology_circleColor: 1 (100.0%) || (37.7%)
#   properties_altitude: 1 (100.0%) || (35.2%)
#   properties_viewed_timestamp: 1 (99.0%) || (59.2%)
#   properties_symbology_lineColor: 0 (100.0%) || (94.3%)
#   properties_symbology_lineWidth: 0 (100.0%) || (94.3%)
#   properties_symbology_lineDasharray: 0 (100.0%) || (94.3%)
#   properties_gps_accuracy: 1 (100.0%) || (29.1%)
#   properties_notesTimestamp: 0 (100.0%) || (95.8%)
# ** Important Feature - properties_symbology_circleColor: 1 (100.0%) || (37.7%)
# ** Important Feature - properties_altitude: 1 (100.0%) || (35.2%)
# ** Important Feature - properties_gps_accuracy: 1 (100.0%) || (29.1%)
#
# ==================================================
# Cluster 2
# ==================================================
# Size: 2650 samples
#
# Distinguishing features:
#   properties_trace_trace_feature: 1 (94.5%) || (10.6%)
#   properties_trace_trace_type: 1 (94.5%) || (10.6%)
#   properties_orientation_data: 0 (98.5%) || (34.4%)
#   properties_notes: 0 (96.4%) || (91.9%)
#   properties_trace_trace_quality: 1 (94.5%) || (9.7%)
#   properties_symbology_circleColor: 0 (100.0%) || (62.3%)
#   properties_altitude: 0 (100.0%) || (64.8%)
#   properties_viewed_timestamp: 1 (97.4%) || (59.2%)
#   properties_symbology_lineColor: 1 (100.0%) || (5.7%)
#   properties_symbology_lineWidth: 1 (100.0%) || (5.7%)
#   properties_symbology_lineDasharray: 1 (100.0%) || (5.7%)
#   properties_gps_accuracy: 0 (100.0%) || (70.9%)
#   properties_notesTimestamp: 0 (96.3%) || (95.8%)
# ** Important Feature - properties_trace_trace_feature: 1 (94.5%) || (10.6%)
# ** Important Feature - properties_trace_trace_type: 1 (94.5%) || (10.6%)
# ** Important Feature - properties_orientation_data: 0 (98.5%) || (34.4%)
# ** Important Feature - properties_trace_trace_quality: 1 (94.5%) || (9.7%)
# ** Important Feature - properties_symbology_lineColor: 1 (100.0%) || (5.7%)
# ** Important Feature - properties_symbology_lineWidth: 1 (100.0%) || (5.7%)
# ** Important Feature - properties_symbology_lineDasharray: 1 (100.0%) || (5.7%)
#
# ==================================================
# Cluster 3
# ==================================================
# Size: 8452 samples
#
# Distinguishing features:
#   properties_trace_trace_feature: 0 (71.7%) || (89.4%)
#   properties_trace_trace_type: 0 (71.7%) || (89.4%)
#   properties_orientation_data: 0 (100.0%) || (34.4%)
#   properties_notes: 0 (86.6%) || (91.9%)
#   properties_trace_trace_quality: 0 (76.7%) || (90.3%)
#   properties_symbology_circleColor: 0 (99.1%) || (62.3%)
#   properties_altitude: 0 (89.9%) || (64.8%)
#   properties_viewed_timestamp: 0 (100.0%) || (40.8%)
#   properties_symbology_lineColor: 0 (100.0%) || (94.3%)
#   properties_symbology_lineWidth: 0 (100.0%) || (94.3%)
#   properties_symbology_lineDasharray: 0 (100.0%) || (94.3%)
#   properties_gps_accuracy: 0 (99.7%) || (70.9%)
#   properties_notesTimestamp: 0 (99.9%) || (95.8%)
# ** Important Feature - properties_orientation_data: 0 (100.0%) || (34.4%)
# ** Important Feature - properties_viewed_timestamp: 0 (100.0%) || (40.8%)
#
# ==================================================
# Cluster 4
# ==================================================
# Size: 7516 samples
#
# Distinguishing features:
#   properties_trace_trace_feature: 0 (100.0%) || (89.4%)
#   properties_trace_trace_type: 0 (100.0%) || (89.4%)
#   properties_orientation_data: 1 (88.9%) || (65.6%)
#   properties_notes: 0 (100.0%) || (91.9%)
#   properties_trace_trace_quality: 0 (100.0%) || (90.3%)
#   properties_symbology_circleColor: 0 (100.0%) || (62.3%)
#   properties_altitude: 1 (100.0%) || (35.2%)
#   properties_viewed_timestamp: 1 (99.0%) || (59.2%)
#   properties_symbology_lineColor: 0 (100.0%) || (94.3%)
#   properties_symbology_lineWidth: 0 (100.0%) || (94.3%)
#   properties_symbology_lineDasharray: 0 (100.0%) || (94.3%)
#   properties_gps_accuracy: 1 (100.0%) || (29.1%)
#   properties_notesTimestamp: 0 (100.0%) || (95.8%)
# ** Important Feature - properties_altitude: 1 (100.0%) || (35.2%)
# ** Important Feature - properties_gps_accuracy: 1 (100.0%) || (29.1%)
#
# ==================================================
# Cluster 5
# ==================================================
# Size: 8421 samples
#
# Distinguishing features:
#   properties_trace_trace_feature: 0 (99.0%) || (89.4%)
#   properties_trace_trace_type: 0 (99.0%) || (89.4%)
#   properties_orientation_data: 1 (100.0%) || (65.6%)
#   properties_notes: 0 (92.9%) || (91.9%)
#   properties_trace_trace_quality: 0 (99.1%) || (90.3%)
#   properties_symbology_circleColor: 0 (98.7%) || (62.3%)
#   properties_altitude: 0 (100.0%) || (64.8%)
#   properties_viewed_timestamp: 0 (100.0%) || (40.8%)
#   properties_symbology_lineColor: 0 (100.0%) || (94.3%)
#   properties_symbology_lineWidth: 0 (100.0%) || (94.3%)
#   properties_symbology_lineDasharray: 0 (100.0%) || (94.3%)
#   properties_gps_accuracy: 0 (100.0%) || (70.9%)
#   properties_notesTimestamp: 0 (100.0%) || (95.8%)
# ** Important Feature - properties_viewed_timestamp: 0 (100.0%) || (40.8%)
#
# ==================================================
# Cluster 6
# ==================================================
# Size: 2055 samples
#
# Distinguishing features:
#   properties_trace_trace_feature: 0 (99.9%) || (89.4%)
#   properties_trace_trace_type: 0 (99.9%) || (89.4%)
#   properties_orientation_data: 1 (100.0%) || (65.6%)
#   properties_notes: 0 (93.5%) || (91.9%)
#   properties_trace_trace_quality: 0 (99.9%) || (90.3%)
#   properties_symbology_circleColor: 0 (100.0%) || (62.3%)
#   properties_altitude: 1 (100.0%) || (35.2%)
#   properties_viewed_timestamp: 0 (100.0%) || (40.8%)
#   properties_symbology_lineColor: 0 (100.0%) || (94.3%)
#   properties_symbology_lineWidth: 0 (100.0%) || (94.3%)
#   properties_symbology_lineDasharray: 0 (100.0%) || (94.3%)
#   properties_gps_accuracy: 0 (100.0%) || (70.9%)
#   properties_notesTimestamp: 0 (100.0%) || (95.8%)
# ** Important Feature - properties_altitude: 1 (100.0%) || (35.2%)
# ** Important Feature - properties_viewed_timestamp: 0 (100.0%) || (40.8%)
#
# ==================================================
# Cluster 7
# ==================================================
# Size: 10927 samples
#
# Distinguishing features:
#   properties_trace_trace_feature: 0 (100.0%) || (89.4%)
#   properties_trace_trace_type: 0 (100.0%) || (89.4%)
#   properties_orientation_data: 1 (75.8%) || (65.6%)
#   properties_notes: 0 (100.0%) || (91.9%)
#   properties_trace_trace_quality: 0 (100.0%) || (90.3%)
#   properties_symbology_circleColor: 1 (100.0%) || (37.7%)
#   properties_altitude: 0 (100.0%) || (64.8%)
#   properties_viewed_timestamp: 1 (100.0%) || (59.2%)
#   properties_symbology_lineColor: 0 (100.0%) || (94.3%)
#   properties_symbology_lineWidth: 0 (100.0%) || (94.3%)
#   properties_symbology_lineDasharray: 0 (100.0%) || (94.3%)
#   properties_gps_accuracy: 0 (100.0%) || (70.9%)
#   properties_notesTimestamp: 0 (99.9%) || (95.8%)
# ** Important Feature - properties_symbology_circleColor: 1 (100.0%) || (37.7%)

# %%
len(unique_modes_features)
# Out:
# 13
