# %% [markdown]
# The purpose of this notebook is to cluster the data. I decided on using KModes to cluster which looks at the mode (most frequently occuring value) and
# the dissimilarity of the data. The lesser the dissimlarities, the more similar the data is to each other. KModes is specifically designed to be used
# on categorical and binary data which sets it apart from other clustering algorithms like KMeans which assume that the data is continous and calculates
# the euclidean distance between points. Another potential clustering algorithm that could be used is HDBScan or DBScan, however, a significant amount of
# tuning would be necessary to get accurate results.

# %%
import pandas as pd
from kmodes.kmodes import KModes
import numpy as np
from sklearn.feature_selection import SelectKBest, chi2, f_classif
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_csv("../data/parquets/processed_parquet.csv")

# %%
def val_count(data):
    counter = 0
    for i in data.columns[0:3]: #don't slice to see the full data
        print(counter)
        print(data[i].value_counts())
        counter += 1
        print("=========================="*5)
    print(data.shape)

# %%
# val_count(df)

# %% [markdown]
# Use this cell to find optimal k values (clusters) for KMODES with an elbow curve. Look for the elbow, where the graph sharply bends.
# Cost is a measure of how well the clustering fits the data. A lower costs means that the data is closer to the centroid, indicating
# a better fit, while a higher cost is a worse fit because the data is farther from the clusters. Optimal K values is 6.

# %%
print(df.shape)
cost = []
K = range(1,12)
for k in list(K):
    kmode = KModes(n_clusters=k, init = "Huang", n_init = 4, verbose=1) #using init = huang because the initialization is random and is computationally faster while achieving the same/better clustering results than Cao
    kmode.fit_predict(df)
    cost.append(kmode.cost_)
    
plt.plot(K, cost, 'o-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Curve')
plt.show()
# Out:
# (1359415, 442)
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 2905049.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 2905049.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 2905049.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 2905049.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 155414, cost: 2457726.0
# Run 1, iteration: 2/100, moves: 71798, cost: 2457726.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 150146, cost: 2517896.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 106408, cost: 2382059.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 13, cost: 2594051.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 540, cost: 2207650.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 8334, cost: 2782447.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 2285552.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 287073, cost: 2194844.0
# Run 4, iteration: 2/100, moves: 4461, cost: 2194844.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 223003, cost: 1987445.0
# Run 1, iteration: 2/100, moves: 2936, cost: 1987445.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 114680, cost: 2181346.0
# Run 2, iteration: 2/100, moves: 15438, cost: 2181346.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 58032, cost: 2167851.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 15305, cost: 2217537.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 195936, cost: 2031478.0
# Run 1, iteration: 2/100, moves: 113, cost: 2031478.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 165497, cost: 1715515.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 127105, cost: 1997260.0
# Run 3, iteration: 2/100, moves: 4719, cost: 1997260.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 82614, cost: 1944409.0
# Run 4, iteration: 2/100, moves: 885, cost: 1944409.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 84734, cost: 2019952.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 324313, cost: 1946553.0
# Run 2, iteration: 2/100, moves: 4766, cost: 1946553.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 310707, cost: 1632290.0
# Run 3, iteration: 2/100, moves: 9625, cost: 1632290.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 235218, cost: 1546367.0
# Run 4, iteration: 2/100, moves: 10028, cost: 1546367.0
# Best run was number 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 101121, cost: 1741379.0
# Run 1, iteration: 2/100, moves: 54249, cost: 1741379.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 164589, cost: 1712141.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 13693, cost: 1861292.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 90920, cost: 1802561.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 116365, cost: 1746457.0
# Run 1, iteration: 2/100, moves: 0, cost: 1746457.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 49941, cost: 1932487.0
# Run 2, iteration: 2/100, moves: 92, cost: 1932487.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 134043, cost: 1646196.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 7671, cost: 1773543.0
# Run 4, iteration: 2/100, moves: 5, cost: 1773543.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 196088, cost: 1676119.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 23523, cost: 1752512.0
# Run 2, iteration: 2/100, moves: 4, cost: 1752512.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 183082, cost: 1332525.0
# Run 3, iteration: 2/100, moves: 49672, cost: 1332525.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 154527, cost: 1722628.0
# Run 4, iteration: 2/100, moves: 20601, cost: 1722628.0
# Best run was number 3

# %% [markdown]
# Use this cell to find optimal k value for KMODES with a Silhouette Score curve. More accurate than elbow graph, but significatly more time consuming.
# A Sillhouette score is a measure of how well a data point fits within the assigned cluster, a higher score means that the data is closely clustered together, a score near 0 indicates that points overlap or on the boundaries of other clusters, and a negative score indicates that points are in completely wrong clusters. To read the graph, choose the cluster with the highest Sillhouette score while also balancing the lowest number of clusters. Optimal K values is 6. Using either elbow graph or sillhouette score will work fine.

# %%
print(df.shape)
results = {}
K = range(2,10)
for k in list(K):
    kmode = KModes(n_clusters=k, init = "Huang", n_init = 2, verbose=1) #Make sure to change the n_init argument as needed to speedup compile time
    clusters = kmode.fit_predict(df)
    db_index = silhouette_score(df, clusters, metric= "hamming") #MUST use hamming metric because data is binary
    results[k] = db_index
    

plt.plot(list(results.keys()), list(results.values()))
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette Score")
plt.show()

# %%
# clusters the data. Use the k amount of clusters found in either the elbow curve or Sillhouette Score curve for n_clusters.
km = KModes(n_clusters= 9, init = "Huang" , n_init= 20).fit(df)
df["cluster"] = km.labels_

# val_count(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # clusters the data. Use the k amount of clusters found in either the elbow curve or Sillhouette Score curve for n_clusters.
# ----> 2 km = KModes(n_clusters= 9, init = "Huang" , n_init= 20).fit(df)
#       3 df["cluster"] = km.labels_
#       5 # val_count(df)
#
# File ~/repos/StraboSpot/.venv/lib/python3.13/site-packages/kmodes/kmodes.py:134, in KModes.fit(self, X, y, sample_weight, **kwargs)
#     129 random_state = check_random_state(self.random_state)
#     130 _validate_sample_weight(sample_weight, n_samples=X.shape[0],
#     131                         n_clusters=self.n_clusters)
#     133 self._enc_cluster_centroids, self._enc_map, self.labels_, self.cost_, \
# --> 134 self.n_iter_, self.epoch_costs_ = k_modes(
#     135     X,
#     136     self.n_clusters,
#     137     self.max_iter,
#     138     self.cat_dissim,
#     139     self.init,
#     140     self.n_init,
#     141     self.verbose,
#     142     random_state,
#     143     self.n_jobs,
#     144     sample_weight
#     145 )
#     146 return self
#
# File ~/repos/StraboSpot/.venv/lib/python3.13/site-packages/kmodes/kmodes.py:241, in k_modes(X, n_clusters, max_iter, dissim, init, n_init, verbose, random_state, n_jobs, sample_weight)
#     239 if n_jobs == 1:
#     240     for init_no in range(n_init):
# --> 241         results.append(_k_modes_single(
#     242             X, n_clusters, n_points, n_attrs, max_iter, dissim, init, init_no,
#     243             verbose, seeds[init_no], sample_weight
#     244         ))
#     245 else:
#     246     results = Parallel(n_jobs=n_jobs, verbose=0)(
#     247         delayed(_k_modes_single)(X, n_clusters, n_points, n_attrs, max_iter,
#     248                                  dissim, init, init_no, verbose, seed, sample_weight)
#     249         for init_no, seed in enumerate(seeds))
#
# File ~/repos/StraboSpot/.venv/lib/python3.13/site-packages/kmodes/kmodes.py:305, in _k_modes_single(X, n_clusters, n_points, n_attrs, max_iter, dissim, init, init_no, verbose, random_state, sample_weight)
#     303 for ik in range(n_clusters):
#     304     for iattr in range(n_attrs):
# --> 305         if sum(membship[ik]) == 0:
#     306             # Empty centroid, choose randomly
#     307             centroids[ik, iattr] = random_state.choice(X[:, iattr])
#     308         else:
#
# KeyboardInterrupt:

# %%
df.to_csv("../data/parquets/kmodes_clustered_parquet.csv", index= False)

# %%
with open('../models/kmodes_model_parquet.pkl', 'wb') as f:
    pickle.dump(km, f)

# %% [markdown]
# Sillhouette score is to measure how well the clustering went. Any score of 0.5 or higher is generally good and indicates that the data is more closely associated with its own cluster than other clusters. Scores close to 1 indicate clear seperations, scores near 0 mean clustering is more uncertain, and scores near -1 indicate that there has likely been misclassifcation. For this measurement, it is necessary to use the Hamming metric as the data that is used is now binary. The Hamming Metric takes a look at the dissimilarity in the data, which is necessary because the binary data prevents the use of the tradictional Euclidean distance metric.

# %%
print(f"Silhouette Score: {silhouette_score(df.drop(columns= "cluster"), df["cluster"], metric= "hamming",sample_size=500000)}")

# %%
print(f"Silhouette Score: {silhouette_score(df.drop(columns= "cluster"), df["cluster"], metric= "jaccard", sample_size= 500000)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f"Silhouette Score: {silhouette_score(df.drop(columns= "cluster"), df["cluster"], metric= "jaccard")}")
#
# NameError: name 'silhouette_score' is not defined
